# %%
# %pylab inline

# %%
import dataiku
from dataiku import pandasutils as pdu
import pandas as pd

# %%
# Example: load a DSS dataset as a Pandas dataframe
mydataset = dataiku.Dataset("mydataset")
mydataset_df = mydataset.get_dataframe()

# %%
import dataiku

# client initialization:
client = dataiku.api_client().get_connection("postgresql")
conn.get_info()["params"]['password']

# %%
conn = dataiku.api_client().get_connection("postgresql")
conn.get_location_info()["params"]["password"]

# %%
import dataiku
import datetime

# client initialization:
client = dataiku.api_client()

project_key = "CUSTOMERSCASES"
project = client.get_project(project_key)
project_info = project.get_timeline()
print(project_info["items"][0])

mofification_time = project_info["items"][0]["time"]
date_time = datetime.datetime.fromtimestamp(mofification_time/1000)
print("Project", project_key, "was updated last on", date_time, "by user", project_info["items"][0]["user"])
# Out:
# {'user': 'admin', 'action': 'JUPYTER_NOTEBOOK_EDIT', 'projectKey': 'CUSTOMERSCASES', 'objectType': 'JUPYTER_NOTEBOOK', 'objectId': 'py36 notebook', 'details': {'objectDisplayName': 'py36 notebook', 'userDisplayName': 'Administrator'}, 'time': 1672817656126}
# Project CUSTOMERSCASES was updated last on 2023-01-04 07:34:16.126000 by user admin

# %%
import urllib.request
import dataiku

client = dataiku.api_client()

with urllib.request.urlopen("https://sergeyd.s3.eu-west-1.amazonaws.com/PythonAPI/DKU_TUT_TS_FORECAST.zip") as f:
    try:
        client.prepare_project_import(f).execute()
    except Exception as e:
        print("There was issue installing", url["name"], e)
print("Done")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-1-daa4070aefa2> in <module>
#       4 client = dataiku.api_client()
#       5
# ----> 6 with urllib.request.urlopen("https://sergeyd.s3.eu-west-1.amazonaws.com/PythonAPI/DKU_TUT_TS_FORECAST.zip") as f:
#       7     try:
#       8         client.prepare_project_import(f).execute()
#
# /usr/lib64/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /usr/lib64/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /usr/lib64/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /usr/lib64/python3.6/urllib/request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib64/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /usr/lib64/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %%
import boto3

session = boto3.Session(
    aws_access_key_id="AKIA5G7CKA4J6C7OGMJQ",
    aws_secret_access_key="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"
)

s3 = boto3.client('s3')
response = s3.list_buckets()

# Output the bucket names
print('Existing buckets:')
for bucket in response['Buckets']:
    print(f'  {bucket["Name"]}')
# Out:
# Existing buckets:
#   andrewm-test-bucket
#   atautu-support-test
#   athena-test-alex
#   aws-cloudtrail-logs-908323325715-44615586
#   aws-logs-908323325715-ap-northeast-1
#   aws-logs-908323325715-eu-west-1
#   aws-logs-908323325715-us-east-1
#   aws-logs-908323325715-us-west-1
#   catalinabucket
#   cf-templates-1rejj8dxasc81-ap-northeast-1
#   cf-templates-1rejj8dxasc81-ap-northeast-2
#   cloudfront-openid-logs20221208113216931900000003
#   cloudfront-openid-static-content20221208113216929500000002
#   config-bucket-908323325715
#   dku-anino
#   dku-anino-automation
#   dku-cr-bucket
#   dku-dgraham-support
#   dku-dgraham-support-2
#   dku-eli-test-bucket
#   dku-elias-support
#   dku-elias-test
#   dku-fm-support-instance
#   dku-hpan-support
#   dku-jonallen-1
#   dku-jordan-support
#   dku-keiji-support
#   dku-keiji-support-2
#   dku-keiji-support-3
#   dku-keiji-support-eu-west-1
#   dku-mike-test
#   dku-mike-test-2
#   dku-sarina-support
#   dku-sarina-supprot-2
#   dku-support-availability
#   dku-support-code
#   dku-support-emr
#   dku-taka-01
#   dku-taka-02
#   dku-zakaria-support
#   dremez01
#   elasticbeanstalk-us-west-1-908323325715
#   ismayil-bucket
#   ismayil-useast-bucket
#   ismayilbucket-euwest1
#   jordan-s3-bucket
#   logarchive-dss
#   santosh-support-test
#   sarina-access-logs-test
#   sarina-ireland
#   sarina-support-bucket
#   sarina-target-instance
#   sergeyd
#   taka-external-test
#   tmp-hpan
#   ysl-private-s3
#   ysl-proxy-s3bucket-x1tpqrigm8kc
#   zach-test-01

# %%
import boto3

session = boto3.Session(
    aws_access_key_id="AKIA5G7CKA4J6C7OGMJQ",
    aws_secret_access_key="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"
)

conn = client('s3')  # again assumes boto.cfg setup, assume AWS S3
for key in conn.list_objects(Bucket='sergeyd')['Contents']:
    print(key['Key'])
# Out:
# PythonAPI/
# PythonAPI/DKU_TUT_TS_FORECAST.zip
# /home/centos/dss/code-envs/python/py36/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)

# %%
import boto3
import dataiku

client = dataiku.api_client()

s3 = boto3.client('s3')
with open('DKU_TUT_TS_FORECAST.zip', 'wb') as f:
    s3.download_fileobj('sergeyd', 'PythonAPI/DKU_TUT_TS_FORECAST.zip', f)
    try:
        client.prepare_project_import(f).execute()
    except Exception as e:
        print("There was issue installing", e)
# Out:
# There was issue installing read
# /home/centos/dss/code-envs/python/py36/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)

# %%
import dataiku

client = dataiku.api_client()
dss_users = client.list_users()

for user in dss_users: 
    if user['userProfile'] == "DESIGNER":
        user_obj = client.get_user(user["login"])
        settings = user_obj.get_settings()
        settings.get_raw()["sourceType"] = "LOCAL"
        settings.save()
        print("User", user["login"], "was set to LOCAL")
# Out:
# User admin2 was set to LOCAL
# User admin3 was set to LOCAL

# %%
client.get_auth_info(with_secrets=True)
# Out:
# {'authSource': 'USER_FROM_UI',
#  'via': ['ticket:jupyter:CUSTOMERSCASES.py36 notebook.ipynb'],
#  'authIdentifier': 'admin',
#  'groups': ['administrators'],
#  'userProfile': 'DATA_SCIENTIST',
#  'associatedDSSUser': 'admin',
#  'userForImpersonation': 'admin',
#  'secrets': [{'key': 'admin', 'value': 'admin'}]}

# %%
import requests
import urllib.request
import dataiku

client = dataiku.api_client()

r = requests.get('https://update.dataiku.com/dss/11.0/plugins/list.json')
for plugin in r.json()["items"]:
    print("--------------------------------\nInstalling plugin:", plugin["meta"]["label"], "...")
    # print(plugin)
    # print(plugin["downloadURL"])
    with urllib.request.urlopen(plugin["downloadURL"]) as f:
        try:
            client.install_plugin_from_archive(f)
        except Exception as e:
            # print("There was issue installing", plugin["meta"]["label"], "plugin.")
            print(e, "\nMaybe it's already installed?")
print("Done")
# Out:
# --------------------------------
# Installing plugin: AB test calculator ...
# There was issue installing AB test calculator plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Airtable ...
# There was issue installing Airtable plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: AKS clusters ...
# There was issue installing AKS clusters plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Algolia Search Connector ...
# There was issue installing Algolia Search Connector plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Amazon Comprehend Medical ...
# There was issue installing Amazon Comprehend Medical plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Amazon Comprehend NLP ...
# There was issue installing Amazon Comprehend NLP plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Amazon Rekognition ...
# There was issue installing Amazon Rekognition plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Amazon Transcribe ...
# There was issue installing Amazon Transcribe plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Data anonymizer ...
# There was issue installing Data anonymizer plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: API Connect ...
# There was issue installing API Connect plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Azure Active Directory Sync ...
# There was issue installing Azure Active Directory Sync plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Azure Cognitive Services - Text Analytics ...
# There was issue installing Azure Cognitive Services - Text Analytics plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Azure Cognitive Services ...
# There was issue installing Azure Cognitive Services plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Box.com ...
# There was issue installing Box.com plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Calendar office365 ...
# There was issue installing Calendar office365 plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Census USA ...
# There was issue installing Census USA plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Co2 converter ...
# There was issue installing Co2 converter plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Confluence wiki ...
# There was issue installing Confluence wiki plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Connections/projects restrictions ...
# There was issue installing Connections/projects restrictions plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Crowlingo Services NLP ...
# There was issue installing Crowlingo Services NLP plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Soundex (custom formula) ...
# There was issue installing Soundex (custom formula) plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Dataproc clusters ...
# There was issue installing Dataproc clusters plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Audits a dataset ...
# There was issue installing Audits a dataset plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Interactive Decision Tree Builder ...
# There was issue installing Interactive Decision Tree Builder plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Deep learning on images (CPU) - Legacy ...
# There was issue installing Deep learning on images (CPU) - Legacy plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Deep learning on images (GPU) - Legacy ...
# There was issue installing Deep learning on images (GPU) - Legacy plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Deep learning on images ...
# There was issue installing Deep learning on images plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Dropbox ...
# There was issue installing Dropbox plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: DynamoDB ...
# There was issue installing DynamoDB plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: EKS clusters ...
# There was issue installing EKS clusters plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Email Tester Suite ...
# There was issue installing Email Tester Suite plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: EMR clusters ...
# There was issue installing EMR clusters plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Esri geo enrichment ...
# There was issue installing Esri geo enrichment plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Feature factory: events-aggregator ...
# There was issue installing Feature factory: events-aggregator plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Excel sheet importer ...
# There was issue installing Excel sheet importer plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Feature engineering using Genetic Algorithm ...
# There was issue installing Feature engineering using Genetic Algorithm plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Sankey charts ...
# There was issue installing Sankey charts plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Freshdesk ...
# There was issue installing Freshdesk plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: GDPR ...
# There was issue installing GDPR plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Generalized Linear Models ...
# There was issue installing Generalized Linear Models plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Reverse geocoding ...
# There was issue installing Reverse geocoding plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Geocoder ...
# There was issue installing Geocoder plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Geo Router ...
# There was issue installing Geo Router plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Zipcode geocoding ...
# There was issue installing Zipcode geocoding plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Get US census block ...
# There was issue installing Get US census block plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Github ...
# There was issue installing Github plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: GKE clusters ...
# There was issue installing GKE clusters plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Google Calendar ...
# There was issue installing Google Calendar plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Google Cloud NLP ...
# There was issue installing Google Cloud NLP plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Google Cloud Vision ...
# There was issue installing Google Cloud Vision plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Google Drive ...
# There was issue installing Google Drive plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Google Sheets ...
# There was issue installing Google Sheets plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Graph analytics ...
# There was issue installing Graph analytics plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Project Gutenberg ...
# There was issue installing Project Gutenberg plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Hierarchical charts ...
# There was issue installing Hierarchical charts plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Holidays ...
# There was issue installing Holidays plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: HubSpot ...
# There was issue installing HubSpot plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Image annotations to Dataset ...
# There was issue installing Image annotations to Dataset plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: import.io ...
# There was issue installing import.io plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Intercom ...
# There was issue installing Intercom plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: IP range matcher ...
# There was issue installing IP range matcher plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Jira ...
# There was issue installing Jira plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Join and keep unmatched ...
# There was issue installing Join and keep unmatched plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Julia ...
# There was issue installing Julia plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Kayrros ...
# There was issue installing Kayrros plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: kdb+ ...
# There was issue installing kdb+ plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: KML Format extractor ...
# There was issue installing KML Format extractor plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: LIBSVM format ...
# There was issue installing LIBSVM format plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: LinkedIn Marketing ...
# There was issue installing LinkedIn Marketing plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: List Folder Contents ...
# There was issue installing List Folder Contents plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Looker Query connector ...
# There was issue installing Looker Query connector plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Mapbox map backgrounds ...
# There was issue installing Mapbox map backgrounds plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: MeaningCloud ...
# There was issue installing MeaningCloud plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Meteonomiqs API ...
# There was issue installing Meteonomiqs API plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Microsoft Power BI v2 ...
# There was issue installing Microsoft Power BI v2 plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Export to MicroStrategy ...
# There was issue installing Export to MicroStrategy plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: ML-assisted Labeling ...
# There was issue installing ML-assisted Labeling plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Model Data Compliance ...
# There was issue installing Model Data Compliance plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Model drift monitoring (deprecated) ...
# There was issue installing Model drift monitoring (deprecated) plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Model Error Analysis ...
# There was issue installing Model Error Analysis plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Model Fairness Report ...
# There was issue installing Model Fairness Report plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: LightGBM (deprecated) ...
# There was issue installing LightGBM (deprecated) plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Model stress test ...
# There was issue installing Model stress test plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Markov Chain Monte-Carlo ...
# There was issue installing Markov Chain Monte-Carlo plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Enrich from Movies APIs ...
# There was issue installing Enrich from Movies APIs plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Multisheet Excel Export ...
# There was issue installing Multisheet Excel Export plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Musixmatch ...
# There was issue installing Musixmatch plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Named Entity Recognition ...
# There was issue installing Named Entity Recognition plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: namR store ...
# There was issue installing namR store plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Natif - Intelligent document processing ...
# There was issue installing Natif - Intelligent document processing plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Neo4j ...
# There was issue installing Neo4j plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Amazon Translation ...
# There was issue installing Amazon Translation plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Text Analysis ...
# There was issue installing Text Analysis plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Azure Translation ...
# There was issue installing Azure Translation plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: DeepL Translation ...
# There was issue installing DeepL Translation plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Google Cloud Translation ...
# There was issue installing Google Cloud Translation plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: NLG Tasks ...
# There was issue installing NLG Tasks plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Offline Translation ...
# There was issue installing Offline Translation plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Text Preparation ...
# There was issue installing Text Preparation plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Text Visualization ...
# There was issue installing Text Visualization plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Numeric base (radix) conversion ...
# There was issue installing Numeric base (radix) conversion plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Object detection in images (CPU) ...
# There was issue installing Object detection in images (CPU) plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Object detection in images (GPU) ...
# There was issue installing Object detection in images (GPU) plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: OData ...
# There was issue installing OData plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Oncrawl ...
# There was issue installing Oncrawl plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: OneDrive ...
# There was issue installing OneDrive plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: ONNX exporter ...
# There was issue installing ONNX exporter plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: OpenWeatherMap ...
# There was issue installing OpenWeatherMap plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Optimization approaches ...
# There was issue installing Optimization approaches plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: OpenStreeMap Enrichment ...
# There was issue installing OpenStreeMap Enrichment plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Pipedrive Import ...
# There was issue installing Pipedrive Import plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Qlik QVX file format ...
# There was issue installing Qlik QVX file format plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Recommendation system ...
# There was issue installing Recommendation system plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Salesforce ...
# There was issue installing Salesforce plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: SAP OData ...
# There was issue installing SAP OData plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: SAS format provided by Pandas ...
# There was issue installing SAS format provided by Pandas plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Send emails ...
# There was issue installing Send emails plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Text Embedding ...
# There was issue installing Text Embedding plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Sentiment Analysis ...
# There was issue installing Sentiment Analysis plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: SharePoint Online ...
# There was issue installing SharePoint Online plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Similarity Search ...
# There was issue installing Similarity Search plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Speech to Text (cpu) ...
# There was issue installing Speech to Text (cpu) plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Speech to Text (gpu) ...
# There was issue installing Speech to Text (gpu) plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Splunk ...
# There was issue installing Splunk plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: SPSS format ...
# There was issue installing SPSS format plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Stripe ...
# There was issue installing Stripe plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Tableau Hyper format ...
# There was issue installing Tableau Hyper format plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Teradata ...
# There was issue installing Teradata plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Tesseract OCR ...
# There was issue installing Tesseract OCR plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Text Summarization ...
# There was issue installing Text Summarization plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Thread ...
# There was issue installing Thread plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Forecast (legacy) ...
# There was issue installing Forecast (legacy) plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Forecast (GPU - CUDA 100) ...
# There was issue installing Forecast (GPU - CUDA 100) plugin.
#
# java.lang.Exception: Could not install the plugin
# Maybe it's already installed?
# --------------------------------
# Installing plugin: Forecast (deprecated) ...
